# %%
import os, shutil
from glob import glob
import numpy as np
import pandas as pd
from natsort import natsorted
import seaborn as sns
from tqdm import tqdm, trange
import matplotlib.pyplot as plt

# %%
in_dir = "out01_tms_induced_respose/"
in_dir2 = "data_subject_info/"

out_dir = "out02_plot_sigals/"
in_file_name = "HRF_tms_induced_response.csv"

if not os.path.exists(out_dir):
    os.mkdir(out_dir)
    
complete_df = pd.read_csv(in_dir + in_file_name)

subject_info = pd.read_csv(in_dir2 + "age_gender_edu.txt", sep = ',')
intensity_suds = pd.read_csv(in_dir2 + "intensity_suds.csv", sep = ',')
scalp_dist = pd.read_csv(in_dir2 + "dist_to_scalp.csv", sep = ',')
print(list(scalp_dist['site'].drop_duplicates()))
# Out:
# ['L-FP', 'R-FP', 'L-aMFG', 'R-aMFG', 'L-pMFG', 'R-pMFG', 'R-IFJ', 'R-FEF', 'R-M1', 'R-preSMA', 'R-IPL']

# %%
# scalp_dist['site'] = scalp_dist['site'].str.replace('-', '_')
# df['range'].str.replace(',','-')

tms_sites = ["L_Fp","R_Fp","L_aMFG","R_aMFG","L_pMFG","R_pMFG","R_IFJ","R_FEF","R_M1","R_preSMA","R_IPL"]
scalp_dist['site'].replace(list(scalp_dist['site'].drop_duplicates()), tms_sites, inplace = True)

# reformat columns in intensity_suds:
intensity_suds = pd.melt(intensity_suds, id_vars=['idall', 'MT', 'intensity'], value_vars = tms_sites,
                         var_name = 'suds_site', value_name = 'suds')

data = subject_info.merge(complete_df, left_on = 'cc_post_intake_id', right_on = 'subject')
data = data.merge(intensity_suds, how = 'left', 
                  left_on = ['cc_post_intake_id', 'site'], right_on = ['idall', 'suds_site'])

data = data.merge(scalp_dist, how = 'left', 
                  left_on = ['subject', 'site'], right_on = ['subject', 'site'])

data.drop(labels = ['inputfile', 'idall', 'cc_post_intake_id', 'suds_site'], axis = 1, inplace = True)
# data.replace({'gender': {1: "male", 2: "female"}}, inplace = True)
# data.replace({'gender': {'male': 1, 'female': 2}}, inplace = True)

data
# Out:
#      gender  age  yrs_of_edu  subject      site group  \
# 0         2   45          18     1001      L_Fp  NTHC
# 1         2   45          18     1001    L_pMFG  NTHC
# 2         2   45          18     1001     R_FEF  NTHC
# 3         2   45          18     1001      R_Fp  NTHC
# 4         2   45          18     1001      R_M1  NTHC
# ..      ...  ...         ...      ...       ...   ...
# 787       1   22          14     2108     R_IPL  TEHC
# 788       1   22          14     2108      R_M1  TEHC
# 789       1   22          14     2108    R_aMFG  TEHC
# 790       1   22          14     2108    R_pMFG  TEHC
# 791       1   22          14     2108  R_preSMA  TEHC
#
#      tms_site_response_standard  tms_site_response_individual_6mm  \
# 0                      0.287125                          0.439684
# 1                     -0.358279                         -0.463813
# 2                     -0.252532                         -0.423779
# 3                      0.245202                          0.278052
# 4                     -1.002989                         -1.403756
# ..                          ...                               ...
# 787                    1.236482                          0.391417
# 788                    0.124382                          0.233850
# 789                   -0.279814                         -0.045608
# 790                    0.363362                         -0.020677
# 791                   -0.939149                         -1.016016
#
#      tms_site_response_individual_10mm  tms_site_response_individual_14mm  \
# 0                             0.456288                           0.395807
# 1                            -0.439631                          -0.329946
# 2                            -0.511036                          -0.496599
# 3                             0.265166                           0.243850
# 4                            -1.606550                          -1.550770
# ..                                 ...                                ...
# 787                           1.001566                           1.383794
# 788                           0.166974                           0.150504
# 789                          -0.032161                          -0.082834
# 790                           0.119496                           0.184963
# 791                          -1.058539                          -1.115993
#
#      tms_site_response_individual_14-10mm  \
# 0                                0.354767
# 1                               -0.264645
# 2                               -0.487678
# 3                                0.230372
# 4                               -1.520768
# ..                                    ...
# 787                              1.611196
# 788                              0.140419
# 789                             -0.115168
# 790                              0.224639
# 791                             -1.151514
#
#      tms_site_response_individual_10-6mm    MT  intensity  suds  scalp_dist
# 0                               0.462649  62.0       74.0  10.0   14.749354
# 1                              -0.431570  62.0       74.0   5.0   13.038824
# 2                              -0.540984  62.0       74.0   2.0   17.079627
# 3                               0.260594  62.0       74.0   7.0   16.614293
# 4                              -1.663231  62.0       74.0   1.0   15.276347
# ..                                   ...   ...        ...   ...         ...
# 787                             1.196951   NaN      100.0   5.0   14.361543
# 788                             0.144036   NaN      100.0  15.0   18.975313
# 789                            -0.027050   NaN      100.0  20.0   13.567683
# 790                             0.165267   NaN      100.0  20.0   14.366030
# 791                            -1.073875   NaN      100.0   5.0   22.010385
#
# [792 rows x 16 columns]

# %%
## correlation matrix:

d = data.loc[:, ['gender', 'age', 'yrs_of_edu', 'MT', 'intensity', 'suds', 'scalp_dist']]
print(d.count())
d.corr()
# Out:
# gender        792
# age           792
# yrs_of_edu    792
# MT            581
# intensity     792
# suds          771
# scalp_dist    689
# dtype: int64
#               gender       age  yrs_of_edu        MT  intensity      suds  \
# gender      1.000000  0.100431    0.030555  0.026028  -0.005011 -0.027004
# age         0.100431  1.000000    0.430420 -0.219282  -0.164505  0.079981
# yrs_of_edu  0.030555  0.430420    1.000000 -0.085059  -0.087906 -0.001968
# MT          0.026028 -0.219282   -0.085059  1.000000   0.999374  0.011761
# intensity  -0.005011 -0.164505   -0.087906  0.999374   1.000000  0.114597
# suds       -0.027004  0.079981   -0.001968  0.011761   0.114597  1.000000
# scalp_dist  0.086767  0.078526    0.044035  0.134476   0.199412 -0.125881
#
#             scalp_dist
# gender        0.086767
# age           0.078526
# yrs_of_edu    0.044035
# MT            0.134476
# intensity     0.199412
# suds         -0.125881
# scalp_dist    1.000000

# %%
import statsmodels
statsmodels.__version__
# Out:
# '0.13.5'

# %%
import statsmodels.api as sm

# backward selection

test_variables = ['tms_site_response_standard', 'tms_site_response_individual_6mm',
                  'tms_site_response_individual_10mm', 'tms_site_response_individual_14mm', 
                  'tms_site_response_individual_14-10mm', 'tms_site_response_individual_10-6mm']

roi_list = data.site.unique()
feature = ['gender', 'age', 'yrs_of_edu', 'intensity', 'suds', 'scalp_dist']

row_index = pd.MultiIndex.from_tuples([(i , j) for i in test_variables for j in feature])
result = pd.DataFrame(index = row_index, columns = tms_sites)

for var in test_variables:    
    for roi in roi_list:
        print(var)
        print(roi)
        
        X = data.loc[(data['site'] == roi) & (~data[var].isna()), feature]
        y = data.loc[(data['site'] == roi) & (~data[var].isna()), [var]]

        if len(y) < 20: continue
            
        # remove nan in X:
        row_nan = X.isna().any(axis=1)
        X = sm.add_constant(X.loc[~row_nan,:]) # adding a constant

        model = sm.OLS(y.loc[~row_nan], X).fit()
        predictions = model.predict(X) 

        print(model.summary())
        for i, f in enumerate(feature):
            result.loc[(var, f), roi] = model.pvalues[i]
# Out:
# tms_site_response_standard
# L_Fp
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     tms_site_response_standard   R-squared:                       0.112
# Model:                                    OLS   Adj. R-squared:                 -0.007
# Method:                         Least Squares   F-statistic:                    0.9437
# Date:                        Thu, 15 Dec 2022   Prob (F-statistic):              0.474
# Time:                                12:37:42   Log-Likelihood:                -48.721
# No. Observations:                          52   AIC:                             111.4
# Df Residuals:                              45   BIC:                             125.1
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9883      1.098      1.810      0.077      -0.224       4.201
# gender        -0.1573      0.187     -0.842      0.404      -0.533       0.219
# age           -0.0038      0.010     -0.392      0.697      -0.023       0.016
# yrs_of_edu    -0.0489      0.046     -1.070      0.290      -0.141       0.043
# intensity     -0.0101      0.010     -1.043      0.303      -0.030       0.009
# suds           0.0035      0.003      1.017      0.315      -0.003       0.010
# scalp_dist    -0.0185      0.026     -0.723      0.474      -0.070       0.033
# ==============================================================================
# Omnibus:                        3.881   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.144   Jarque-Bera (JB):                3.000
# Skew:                          -0.571   Prob(JB):                        0.223
# Kurtosis:                       3.287   Cond. No.                     1.28e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_standard
# L_pMFG
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     tms_site_response_standard   R-squared:                       0.038
# Model:                                    OLS   Adj. R-squared:                 -0.055
# Method:                         Least Squares   F-statistic:                    0.4105
# Date:                        Thu, 15 Dec 2022   Prob (F-statistic):              0.869
# Time:                                12:37:42   Log-Likelihood:                -57.236
# No. Observations:                          69   AIC:                             128.5
# Df Residuals:                              62   BIC:                             144.1
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4993      0.923     -0.541      0.591      -2.345       1.346
# gender        -0.0523      0.146     -0.358      0.722      -0.344       0.240
# age            0.0028      0.008      0.365      0.716      -0.012       0.018
# yrs_of_edu     0.0227      0.036      0.624      0.535      -0.050       0.096
# intensity     -0.0052      0.009     -0.598      0.552      -0.022       0.012
# suds           0.0006      0.004      0.168      0.867      -0.007       0.008
# scalp_dist     0.0309      0.034      0.912      0.365      -0.037       0.099
# ==============================================================================
# Omnibus:                        4.485   Durbin-Watson:                   2.310
# Prob(Omnibus):                  0.106   Jarque-Bera (JB):                3.737
# Skew:                           0.411   Prob(JB):                        0.154
# Kurtosis:                       3.791   Cond. No.                     1.33e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_standard
# R_FEF
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     tms_site_response_standard   R-squared:                       0.101
# Model:                                    OLS   Adj. R-squared:                  0.008
# Method:                         Least Squares   F-statistic:                     1.090
# Date:                        Thu, 15 Dec 2022   Prob (F-statistic):              0.379
# Time:                                12:37:42   Log-Likelihood:                -52.573
# No. Observations:                          65   AIC:                             119.1
# Df Residuals:                              58   BIC:                             134.4
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.8885      0.969     -0.917      0.363      -2.828       1.051
# gender        -0.0370      0.148     -0.250      0.804      -0.334       0.260
# age            0.0003      0.007      0.048      0.962      -0.014       0.015
# yrs_of_edu     0.0692      0.038      1.808      0.076      -0.007       0.146
# intensity      0.0063      0.009      0.727      0.470      -0.011       0.024
# suds          -0.0004      0.004     -0.090      0.929      -0.008       0.008
# scalp_dist    -0.0541      0.031     -1.745      0.086      -0.116       0.008
# ==============================================================================
# Omnibus:                        1.677   Durbin-Watson:                   1.414
# Prob(Omnibus):                  0.432   Jarque-Bera (JB):                0.998
# Skew:                           0.067   Prob(JB):                        0.607
# Kurtosis:                       3.592   Cond. No.                     1.37e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_standard
# R_Fp
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     tms_site_response_standard   R-squared:                       0.023
# Model:                                    OLS   Adj. R-squared:                 -0.101
# Method:                         Least Squares   F-statistic:                    0.1861
# Date:                        Thu, 15 Dec 2022   Prob (F-statistic):              0.979
# Time:                                12:37:42   Log-Likelihood:                -71.465
# No. Observations:                          54   AIC:                             156.9
# Df Residuals:                              47   BIC:                             170.9
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2725      1.706     -0.160      0.874      -3.705       3.160
# gender         0.1719      0.274      0.628      0.533      -0.379       0.723
# age           -0.0048      0.014     -0.338      0.737      -0.034       0.024
# yrs_of_edu     0.0248      0.066      0.377      0.708      -0.108       0.158
# intensity     -0.0016      0.015     -0.105      0.917      -0.031       0.028
# suds          -0.0014      0.006     -0.256      0.799      -0.013       0.010
# scalp_dist    -0.0158      0.039     -0.408      0.685      -0.094       0.062
# ==============================================================================
# Omnibus:                       41.692   Durbin-Watson:                   1.756
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              247.750
# Skew:                          -1.792   Prob(JB):                     1.59e-54
# Kurtosis:                      12.862   Cond. No.                     1.37e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_standard
# R_M1
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     tms_site_response_standard   R-squared:                       0.035
# Model:                                    OLS   Adj. R-squared:                 -0.063
# Method:                         Least Squares   F-statistic:                    0.3576
# Date:                        Thu, 15 Dec 2022   Prob (F-statistic):              0.903
# Time:                                12:37:42   Log-Likelihood:                -69.690
# No. Observations:                          66   AIC:                             153.4
# Df Residuals:                              59   BIC:                             168.7
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7216      1.167      0.618      0.539      -1.613       3.056
# gender        -0.0380      0.187     -0.203      0.840      -0.412       0.336
# age            0.0069      0.010      0.710      0.481      -0.013       0.027
# yrs_of_edu    -0.0682      0.049     -1.382      0.172      -0.167       0.031
# intensity      0.0015      0.010      0.143      0.886      -0.019       0.022
# suds          -0.0005      0.007     -0.069      0.945      -0.015       0.014
# scalp_dist    -0.0111      0.039     -0.287      0.775      -0.089       0.066
# ==============================================================================
# Omnibus:                        3.379   Durbin-Watson:                   1.731
# Prob(Omnibus):                  0.185   Jarque-Bera (JB):                2.782
# Skew:                          -0.257   Prob(JB):                        0.249
# Kurtosis:                       3.864   Cond. No.                     1.28e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_standard
# R_aMFG
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     tms_site_response_standard   R-squared:                       0.109
# Model:                                    OLS   Adj. R-squared:                  0.024
# Method:                         Least Squares   F-statistic:                     1.287
# Date:                        Thu, 15 Dec 2022   Prob (F-statistic):              0.276
# Time:                                12:37:42   Log-Likelihood:                -59.267
# No. Observations:                          70   AIC:                             132.5
# Df Residuals:                              63   BIC:                             148.3
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.8408      0.927     -1.985      0.052      -3.694       0.012
# gender         0.1630      0.147      1.105      0.273      -0.132       0.458
# age            0.0073      0.008      0.966      0.338      -0.008       0.023
# yrs_of_edu     0.0434      0.037      1.168      0.247      -0.031       0.118
# intensity      0.0022      0.008      0.290      0.773      -0.013       0.018
# suds           0.0012      0.003      0.368      0.714      -0.005       0.008
# scalp_dist     0.0255      0.028      0.908      0.368      -0.031       0.082
# ==============================================================================
# Omnibus:                        3.156   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.206   Jarque-Bera (JB):                2.619
# Skew:                          -0.219   Prob(JB):                        0.270
# Kurtosis:                       3.840   Cond. No.                     1.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_standard
# R_pMFG
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     tms_site_response_standard   R-squared:                       0.059
# Model:                                    OLS   Adj. R-squared:                 -0.030
# Method:                         Least Squares   F-statistic:                    0.6633
# Date:                        Thu, 15 Dec 2022   Prob (F-statistic):              0.679
# Time:                                12:37:42   Log-Likelihood:                -64.728
# No. Observations:                          70   AIC:                             143.5
# Df Residuals:                              63   BIC:                             159.2
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3139      1.031     -0.304      0.762      -2.375       1.747
# gender        -0.2514      0.159     -1.584      0.118      -0.569       0.066
# age           -0.0083      0.008     -1.028      0.308      -0.024       0.008
# yrs_of_edu     0.0299      0.040      0.752      0.455      -0.049       0.109
# intensity  -7.046e-05      0.009     -0.007      0.994      -0.019       0.019
# suds           0.0012      0.003      0.335      0.739      -0.006       0.008
# scalp_dist     0.0222      0.035      0.632      0.530      -0.048       0.092
# ==============================================================================
# Omnibus:                        5.548   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.062   Jarque-Bera (JB):                4.688
# Skew:                          -0.581   Prob(JB):                       0.0959
# Kurtosis:                       3.507   Cond. No.                     1.38e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.38e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_standard
# L_aMFG
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     tms_site_response_standard   R-squared:                       0.225
# Model:                                    OLS   Adj. R-squared:                  0.149
# Method:                         Least Squares   F-statistic:                     2.953
# Date:                        Thu, 15 Dec 2022   Prob (F-statistic):             0.0135
# Time:                                12:37:42   Log-Likelihood:                -44.694
# No. Observations:                          68   AIC:                             103.4
# Df Residuals:                              61   BIC:                             118.9
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5456      0.801      0.681      0.498      -1.055       2.147
# gender        -0.3380      0.126     -2.676      0.010      -0.590      -0.085
# age            0.0116      0.007      1.731      0.089      -0.002       0.025
# yrs_of_edu     0.0351      0.030      1.163      0.249      -0.025       0.096
# intensity     -0.0104      0.007     -1.439      0.155      -0.025       0.004
# suds          -0.0008      0.003     -0.286      0.776      -0.007       0.005
# scalp_dist    -0.0091      0.027     -0.337      0.737      -0.063       0.045
# ==============================================================================
# Omnibus:                        0.247   Durbin-Watson:                   1.790
# Prob(Omnibus):                  0.884   Jarque-Bera (JB):                0.418
# Skew:                          -0.106   Prob(JB):                        0.812
# Kurtosis:                       2.680   Cond. No.                     1.37e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_standard
# R_IFJ
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     tms_site_response_standard   R-squared:                       0.079
# Model:                                    OLS   Adj. R-squared:                 -0.017
# Method:                         Least Squares   F-statistic:                    0.8247
# Date:                        Thu, 15 Dec 2022   Prob (F-statistic):              0.555
# Time:                                12:37:42   Log-Likelihood:                -53.795
# No. Observations:                          65   AIC:                             121.6
# Df Residuals:                              58   BIC:                             136.8
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.5860      0.970     -1.635      0.107      -3.528       0.356
# gender        -0.0513      0.154     -0.333      0.740      -0.359       0.257
# age            0.0009      0.008      0.124      0.901      -0.014       0.016
# yrs_of_edu     0.0146      0.037      0.392      0.696      -0.060       0.089
# intensity      0.0164      0.009      1.787      0.079      -0.002       0.035
# suds          -0.0046      0.004     -1.225      0.226      -0.012       0.003
# scalp_dist    -0.0088      0.029     -0.301      0.764      -0.067       0.049
# ==============================================================================
# Omnibus:                       15.560   Durbin-Watson:                   2.340
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.491
# Skew:                          -0.996   Prob(JB):                     5.86e-05
# Kurtosis:                       4.796   Cond. No.                     1.37e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_standard
# R_preSMA
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     tms_site_response_standard   R-squared:                       0.078
# Model:                                    OLS   Adj. R-squared:                 -0.033
# Method:                         Least Squares   F-statistic:                    0.7021
# Date:                        Thu, 15 Dec 2022   Prob (F-statistic):              0.649
# Time:                                12:37:42   Log-Likelihood:                -81.573
# No. Observations:                          57   AIC:                             177.1
# Df Residuals:                              50   BIC:                             191.4
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2566      1.850      0.139      0.890      -3.459       3.972
# gender        -0.3376      0.299     -1.130      0.264      -0.938       0.263
# age           -0.0197      0.016     -1.203      0.235      -0.052       0.013
# yrs_of_edu     0.0547      0.077      0.713      0.479      -0.099       0.209
# intensity     -0.0173      0.019     -0.930      0.357      -0.055       0.020
# suds           0.0029      0.012      0.245      0.807      -0.021       0.027
# scalp_dist     0.0629      0.055      1.146      0.257      -0.047       0.173
# ==============================================================================
# Omnibus:                       12.928   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               36.720
# Skew:                          -0.377   Prob(JB):                     1.06e-08
# Kurtosis:                       6.859   Cond. No.                     1.29e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_standard
# R_IPL
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     tms_site_response_standard   R-squared:                       0.212
# Model:                                    OLS   Adj. R-squared:                  0.030
# Method:                         Least Squares   F-statistic:                     1.166
# Date:                        Thu, 15 Dec 2022   Prob (F-statistic):              0.354
# Time:                                12:37:42   Log-Likelihood:                -22.204
# No. Observations:                          33   AIC:                             58.41
# Df Residuals:                              26   BIC:                             68.88
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.3535      1.580      1.489      0.148      -0.895       5.602
# gender        -0.0741      0.201     -0.369      0.715      -0.486       0.338
# age            0.0042      0.010      0.425      0.674      -0.016       0.025
# yrs_of_edu    -0.0052      0.047     -0.112      0.912      -0.101       0.091
# intensity     -0.0278      0.014     -2.007      0.055      -0.056       0.001
# suds          -0.0111      0.008     -1.404      0.172      -0.027       0.005
# scalp_dist     0.0365      0.040      0.910      0.371      -0.046       0.119
# ==============================================================================
# Omnibus:                        9.856   Durbin-Watson:                   1.385
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                8.666
# Skew:                           1.170   Prob(JB):                       0.0131
# Kurtosis:                       3.911   Cond. No.                     1.73e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.73e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_6mm
# L_Fp
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     tms_site_response_individual_6mm   R-squared:                       0.259
# Model:                                          OLS   Adj. R-squared:                  0.160
# Method:                               Least Squares   F-statistic:                     2.623
# Date:                              Thu, 15 Dec 2022   Prob (F-statistic):             0.0289
# Time:                                      12:37:42   Log-Likelihood:                -31.823
# No. Observations:                                52   AIC:                             77.65
# Df Residuals:                                    45   BIC:                             91.31
# Df Model:                                         6
# Covariance Type:                          nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8401      0.794      2.318      0.025       0.241       3.439
# gender         0.0821      0.135      0.608      0.546      -0.190       0.354
# age           -0.0101      0.007     -1.446      0.155      -0.024       0.004
# yrs_of_edu    -0.0377      0.033     -1.143      0.259      -0.104       0.029
# intensity     -0.0140      0.007     -1.995      0.052      -0.028       0.000
# suds           0.0076      0.002      3.035      0.004       0.003       0.013
# scalp_dist    -0.0024      0.019     -0.132      0.896      -0.040       0.035
# ==============================================================================
# Omnibus:                        3.349   Durbin-Watson:                   2.503
# Prob(Omnibus):                  0.187   Jarque-Bera (JB):                2.512
# Skew:                           0.295   Prob(JB):                        0.285
# Kurtosis:                       3.901   Cond. No.                     1.28e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_6mm
# L_pMFG
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     tms_site_response_individual_6mm   R-squared:                       0.057
# Model:                                          OLS   Adj. R-squared:                 -0.036
# Method:                               Least Squares   F-statistic:                    0.6101
# Date:                              Thu, 15 Dec 2022   Prob (F-statistic):              0.721
# Time:                                      12:37:42   Log-Likelihood:                -79.694
# No. Observations:                                68   AIC:                             173.4
# Df Residuals:                                    61   BIC:                             188.9
# Df Model:                                         6
# Covariance Type:                          nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.7904      1.321     -0.598      0.552      -3.432       1.851
# gender        -0.0619      0.208     -0.297      0.767      -0.478       0.354
# age           -0.0023      0.011     -0.211      0.834      -0.024       0.019
# yrs_of_edu     0.0577      0.052      1.113      0.270      -0.046       0.161
# intensity      0.0070      0.012      0.569      0.572      -0.018       0.032
# suds          -0.0057      0.005     -1.124      0.266      -0.016       0.004
# scalp_dist    -0.0495      0.048     -1.035      0.305      -0.145       0.046
# ==============================================================================
# Omnibus:                        3.959   Durbin-Watson:                   2.364
# Prob(Omnibus):                  0.138   Jarque-Bera (JB):                4.389
# Skew:                          -0.078   Prob(JB):                        0.111
# Kurtosis:                       4.235   Cond. No.                     1.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_6mm
# R_FEF
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     tms_site_response_individual_6mm   R-squared:                       0.044
# Model:                                          OLS   Adj. R-squared:                 -0.055
# Method:                               Least Squares   F-statistic:                    0.4403
# Date:                              Thu, 15 Dec 2022   Prob (F-statistic):              0.849
# Time:                                      12:37:42   Log-Likelihood:                -71.188
# No. Observations:                                65   AIC:                             156.4
# Df Residuals:                                    58   BIC:                             171.6
# Df Model:                                         6
# Covariance Type:                          nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6688      1.290     -0.518      0.606      -3.251       1.914
# gender        -0.0788      0.197     -0.399      0.691      -0.474       0.316
# age           -0.0037      0.010     -0.378      0.707      -0.023       0.016
# yrs_of_edu     0.0421      0.051      0.826      0.412      -0.060       0.144
# intensity      0.0104      0.012      0.905      0.369      -0.013       0.033
# suds           0.0008      0.005      0.149      0.882      -0.010       0.011
# scalp_dist    -0.0510      0.041     -1.236      0.221      -0.134       0.032
# ==============================================================================
# Omnibus:                        8.638   Durbin-Watson:                   1.687
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):               11.311
# Skew:                           0.494   Prob(JB):                      0.00350
# Kurtosis:                       4.789   Cond. No.                     1.37e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_6mm
# R_Fp
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     tms_site_response_individual_6mm   R-squared:                       0.036
# Model:                                          OLS   Adj. R-squared:                 -0.102
# Method:                               Least Squares   F-statistic:                    0.2609
# Date:                              Thu, 15 Dec 2022   Prob (F-statistic):              0.952
# Time:                                      12:37:42   Log-Likelihood:                -64.360
# No. Observations:                                49   AIC:                             142.7
# Df Residuals:                                    42   BIC:                             156.0
# Df Model:                                         6
# Covariance Type:                          nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0749      1.991      0.038      0.970      -3.942       4.092
# gender         0.0258      0.292      0.088      0.930      -0.564       0.615
# age            0.0155      0.016      0.950      0.348      -0.017       0.049
# yrs_of_edu    -0.0006      0.068     -0.008      0.994      -0.138       0.137
# intensity     -0.0021      0.017     -0.124      0.902      -0.036       0.032
# suds          -0.0016      0.006     -0.269      0.789      -0.013       0.010
# scalp_dist    -0.0287      0.039     -0.730      0.469      -0.108       0.051
# ==============================================================================
# Omnibus:                       14.473   Durbin-Watson:                   2.092
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               48.126
# Skew:                          -0.426   Prob(JB):                     3.54e-11
# Kurtosis:                       7.780   Cond. No.                     1.53e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.53e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_6mm
# R_M1
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     tms_site_response_individual_6mm   R-squared:                       0.086
# Model:                                          OLS   Adj. R-squared:                 -0.010
# Method:                               Least Squares   F-statistic:                    0.8932
# Date:                              Thu, 15 Dec 2022   Prob (F-statistic):              0.506
# Time:                                      12:37:42   Log-Likelihood:                -81.919
# No. Observations:                                64   AIC:                             177.8
# Df Residuals:                                    57   BIC:                             192.9
# Df Model:                                         6
# Covariance Type:                          nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.3373      1.465      0.913      0.365      -1.596       4.271
# gender         0.0666      0.238      0.280      0.780      -0.409       0.542
# age            0.0205      0.012      1.663      0.102      -0.004       0.045
# yrs_of_edu    -0.1061      0.062     -1.715      0.092      -0.230       0.018
# intensity     -0.0056      0.013     -0.433      0.666      -0.031       0.020
# suds          -0.0091      0.010     -0.909      0.367      -0.029       0.011
# scalp_dist    -0.0017      0.049     -0.034      0.973      -0.099       0.096
# ==============================================================================
# Omnibus:                        6.776   Durbin-Watson:                   1.606
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):                9.213
# Skew:                           0.315   Prob(JB):                      0.00999
# Kurtosis:                       4.749   Cond. No.                     1.26e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_6mm
# R_aMFG
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     tms_site_response_individual_6mm   R-squared:                       0.034
# Model:                                          OLS   Adj. R-squared:                 -0.058
# Method:                               Least Squares   F-statistic:                    0.3725
# Date:                              Thu, 15 Dec 2022   Prob (F-statistic):              0.894
# Time:                                      12:37:42   Log-Likelihood:                -66.246
# No. Observations:                                70   AIC:                             146.5
# Df Residuals:                                    63   BIC:                             162.2
# Df Model:                                         6
# Covariance Type:                          nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1232      1.025     -0.120      0.905      -2.171       1.924
# gender         0.0228      0.163      0.140      0.889      -0.303       0.348
# age            0.0055      0.008      0.658      0.513      -0.011       0.022
# yrs_of_edu     0.0050      0.041      0.122      0.903      -0.077       0.087
# intensity     -0.0051      0.009     -0.594      0.555      -0.022       0.012
# suds           0.0037      0.004      1.013      0.315      -0.004       0.011
# scalp_dist     0.0044      0.031      0.143      0.887      -0.058       0.066
# ==============================================================================
# Omnibus:                        5.935   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.051   Jarque-Bera (JB):                7.069
# Skew:                          -0.315   Prob(JB):                       0.0292
# Kurtosis:                       4.424   Cond. No.                     1.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_6mm
# R_pMFG
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     tms_site_response_individual_6mm   R-squared:                       0.022
# Model:                                          OLS   Adj. R-squared:                 -0.075
# Method:                               Least Squares   F-statistic:                    0.2241
# Date:                              Thu, 15 Dec 2022   Prob (F-statistic):              0.967
# Time:                                      12:37:42   Log-Likelihood:                -78.929
# No. Observations:                                68   AIC:                             171.9
# Df Residuals:                                    61   BIC:                             187.4
# Df Model:                                         6
# Covariance Type:                          nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1035      1.347      0.077      0.939      -2.589       2.796
# gender        -0.1151      0.206     -0.560      0.578      -0.527       0.296
# age           -0.0038      0.010     -0.368      0.714      -0.024       0.017
# yrs_of_edu     0.0165      0.051      0.321      0.750      -0.086       0.119
# intensity     -0.0027      0.012     -0.223      0.825      -0.027       0.022
# suds          -0.0033      0.004     -0.736      0.465      -0.012       0.006
# scalp_dist     0.0094      0.045      0.210      0.834      -0.080       0.099
# ==============================================================================
# Omnibus:                       33.215   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.823
# Skew:                          -1.510   Prob(JB):                     8.50e-20
# Kurtosis:                       7.678   Cond. No.                     1.40e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_6mm
# L_aMFG
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     tms_site_response_individual_6mm   R-squared:                       0.230
# Model:                                          OLS   Adj. R-squared:                  0.154
# Method:                               Least Squares   F-statistic:                     3.029
# Date:                              Thu, 15 Dec 2022   Prob (F-statistic):             0.0117
# Time:                                      12:37:42   Log-Likelihood:                -59.187
# No. Observations:                                68   AIC:                             132.4
# Df Residuals:                                    61   BIC:                             147.9
# Df Model:                                         6
# Covariance Type:                          nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1031      0.991      1.113      0.270      -0.878       3.084
# gender        -0.2305      0.156     -1.475      0.145      -0.543       0.082
# age            0.0186      0.008      2.238      0.029       0.002       0.035
# yrs_of_edu     0.0424      0.037      1.134      0.261      -0.032       0.117
# intensity     -0.0181      0.009     -2.025      0.047      -0.036      -0.000
# suds          -0.0013      0.004     -0.368      0.714      -0.009       0.006
# scalp_dist    -0.0315      0.033     -0.942      0.350      -0.098       0.035
# ==============================================================================
# Omnibus:                        4.049   Durbin-Watson:                   1.789
# Prob(Omnibus):                  0.132   Jarque-Bera (JB):                3.170
# Skew:                          -0.478   Prob(JB):                        0.205
# Kurtosis:                       3.452   Cond. No.                     1.37e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_6mm
# R_IFJ
#                                    OLS Regression Results
# ...
# Kurtosis:                       4.302   Cond. No.                     1.28e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_10-6mm
# R_aMFG
#                                      OLS Regression Results
# ===============================================================================================
# Dep. Variable:     tms_site_response_individual_10-6mm   R-squared:                       0.041
# Model:                                             OLS   Adj. R-squared:                 -0.050
# Method:                                  Least Squares   F-statistic:                    0.4538
# Date:                                 Thu, 15 Dec 2022   Prob (F-statistic):              0.840
# Time:                                         12:37:42   Log-Likelihood:                -60.053
# No. Observations:                                   70   AIC:                             134.1
# Df Residuals:                                       63   BIC:                             149.8
# Df Model:                                            6
# Covariance Type:                             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.8014      0.938     -0.854      0.396      -2.676       1.073
# gender         0.0753      0.149      0.505      0.615      -0.223       0.373
# age            0.0031      0.008      0.400      0.690      -0.012       0.018
# yrs_of_edu     0.0286      0.038      0.760      0.450      -0.047       0.104
# intensity     -0.0022      0.008     -0.286      0.776      -0.018       0.013
# suds           0.0028      0.003      0.826      0.412      -0.004       0.010
# scalp_dist     0.0114      0.028      0.400      0.691      -0.045       0.068
# ==============================================================================
# Omnibus:                        2.883   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.237   Jarque-Bera (JB):                2.576
# Skew:                          -0.062   Prob(JB):                        0.276
# Kurtosis:                       3.932   Cond. No.                     1.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_10-6mm
# R_pMFG
#                                      OLS Regression Results
# ===============================================================================================
# Dep. Variable:     tms_site_response_individual_10-6mm   R-squared:                       0.026
# Model:                                             OLS   Adj. R-squared:                 -0.067
# Method:                                  Least Squares   F-statistic:                    0.2804
# Date:                                 Thu, 15 Dec 2022   Prob (F-statistic):              0.944
# Time:                                         12:37:42   Log-Likelihood:                -70.847
# No. Observations:                                   70   AIC:                             155.7
# Df Residuals:                                       63   BIC:                             171.4
# Df Model:                                            6
# Covariance Type:                             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0237      1.126      0.021      0.983      -2.226       2.273
# gender        -0.1543      0.173     -0.891      0.377      -0.501       0.192
# age           -0.0067      0.009     -0.765      0.447      -0.024       0.011
# yrs_of_edu     0.0171      0.043      0.395      0.694      -0.069       0.104
# intensity     -0.0006      0.010     -0.061      0.952      -0.021       0.020
# suds          -0.0013      0.004     -0.331      0.742      -0.009       0.006
# scalp_dist     0.0060      0.038      0.157      0.876      -0.071       0.083
# ==============================================================================
# Omnibus:                       15.912   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.449
# Skew:                          -0.874   Prob(JB):                     8.09e-06
# Kurtosis:                       5.232   Cond. No.                     1.38e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.38e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_10-6mm
# L_aMFG
#                                      OLS Regression Results
# ===============================================================================================
# Dep. Variable:     tms_site_response_individual_10-6mm   R-squared:                       0.247
# Model:                                             OLS   Adj. R-squared:                  0.173
# Method:                                  Least Squares   F-statistic:                     3.336
# Date:                                 Thu, 15 Dec 2022   Prob (F-statistic):            0.00660
# Time:                                         12:37:43   Log-Likelihood:                -50.193
# No. Observations:                                   68   AIC:                             114.4
# Df Residuals:                                       61   BIC:                             129.9
# Df Model:                                            6
# Covariance Type:                             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9997      0.868      1.152      0.254      -0.736       2.735
# gender        -0.2852      0.137     -2.083      0.041      -0.559      -0.011
# age            0.0143      0.007      1.964      0.054      -0.000       0.029
# yrs_of_edu     0.0431      0.033      1.315      0.193      -0.022       0.109
# intensity     -0.0172      0.008     -2.200      0.032      -0.033      -0.002
# suds          -0.0005      0.003     -0.148      0.883      -0.007       0.006
# scalp_dist    -0.0166      0.029     -0.568      0.572      -0.075       0.042
# ==============================================================================
# Omnibus:                        0.369   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.832   Jarque-Bera (JB):                0.297
# Skew:                          -0.156   Prob(JB):                        0.862
# Kurtosis:                       2.915   Cond. No.                     1.37e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_10-6mm
# R_IFJ
#                                      OLS Regression Results
# ===============================================================================================
# Dep. Variable:     tms_site_response_individual_10-6mm   R-squared:                       0.100
# Model:                                             OLS   Adj. R-squared:                  0.007
# Method:                                  Least Squares   F-statistic:                     1.071
# Date:                                 Thu, 15 Dec 2022   Prob (F-statistic):              0.390
# Time:                                         12:37:43   Log-Likelihood:                -50.654
# No. Observations:                                   65   AIC:                             115.3
# Df Residuals:                                       58   BIC:                             130.5
# Df Model:                                            6
# Covariance Type:                             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.6768      0.924     -1.814      0.075      -3.527       0.173
# gender        -0.0840      0.147     -0.573      0.569      -0.378       0.209
# age            0.0051      0.007      0.706      0.483      -0.009       0.019
# yrs_of_edu     0.0085      0.035      0.240      0.811      -0.062       0.079
# intensity      0.0191      0.009      2.190      0.033       0.002       0.037
# suds          -0.0032      0.004     -0.894      0.375      -0.010       0.004
# scalp_dist    -0.0216      0.028     -0.779      0.439      -0.077       0.034
# ==============================================================================
# Omnibus:                        3.985   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.136   Jarque-Bera (JB):                3.846
# Skew:                          -0.225   Prob(JB):                        0.146
# Kurtosis:                       4.104   Cond. No.                     1.37e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_10-6mm
# R_preSMA
#                                      OLS Regression Results
# ===============================================================================================
# Dep. Variable:     tms_site_response_individual_10-6mm   R-squared:                       0.114
# Model:                                             OLS   Adj. R-squared:                  0.008
# Method:                                  Least Squares   F-statistic:                     1.077
# Date:                                 Thu, 15 Dec 2022   Prob (F-statistic):              0.389
# Time:                                         12:37:43   Log-Likelihood:                -91.131
# No. Observations:                                   57   AIC:                             196.3
# Df Residuals:                                       50   BIC:                             210.6
# Df Model:                                            6
# Covariance Type:                             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5858      2.187      0.725      0.472      -2.808       5.979
# gender        -0.5951      0.353     -1.684      0.098      -1.305       0.115
# age           -0.0256      0.019     -1.328      0.190      -0.064       0.013
# yrs_of_edu     0.0525      0.091      0.578      0.566      -0.130       0.235
# intensity     -0.0269      0.022     -1.225      0.226      -0.071       0.017
# suds           0.0001      0.014      0.007      0.994      -0.028       0.028
# scalp_dist     0.0695      0.065      1.071      0.289      -0.061       0.200
# ==============================================================================
# Omnibus:                       11.373   Durbin-Watson:                   1.906
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               34.471
# Skew:                          -0.117   Prob(JB):                     3.27e-08
# Kurtosis:                       6.803   Cond. No.                     1.29e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# tms_site_response_individual_10-6mm
# R_IPL
#                                      OLS Regression Results
# ===============================================================================================
# Dep. Variable:     tms_site_response_individual_10-6mm   R-squared:                       0.188
# Model:                                             OLS   Adj. R-squared:                  0.001
# Method:                                  Least Squares   F-statistic:                     1.004
# Date:                                 Thu, 15 Dec 2022   Prob (F-statistic):              0.444
# Time:                                         12:37:43   Log-Likelihood:                -20.560
# No. Observations:                                   33   AIC:                             55.12
# Df Residuals:                                       26   BIC:                             65.60
# Df Model:                                            6
# Covariance Type:                             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.5144      1.504      1.672      0.106      -0.576       5.605
# gender        -0.0368      0.191     -0.193      0.849      -0.429       0.355
# age            0.0084      0.009      0.886      0.384      -0.011       0.028
# yrs_of_edu    -0.0130      0.044     -0.294      0.771      -0.104       0.078
# intensity     -0.0251      0.013     -1.901      0.068      -0.052       0.002
# suds          -0.0088      0.008     -1.177      0.250      -0.024       0.007
# scalp_dist     0.0036      0.038      0.094      0.926      -0.075       0.082
# ==============================================================================
# Omnibus:                        2.069   Durbin-Watson:                   1.502
# Prob(Omnibus):                  0.355   Jarque-Bera (JB):                1.537
# Skew:                           0.528   Prob(JB):                        0.464
# Kurtosis:                       2.930   Cond. No.                     1.73e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.73e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
def format_table(report):
    report2 = report.copy()
    report2[report.gt(0)] = report2[report.gt(0)].astype(str).apply(lambda x : x.str[:5])
    
    report2[report.le(0.05)] = \
    report2[report.le(0.05)].apply(lambda x : x.str[:5]).add('*')

    report2[report.le(0.01)] = \
    report2[report.le(0.01)].apply(lambda x : x.str[:5]).add('**')
        
    return report2

result2 = format_table(result)
result2.to_csv(out_dir + "multiple_regression_pvalues.csv")
result2
# Out:
#                                                     L_Fp   R_Fp   L_aMFG  \
# tms_site_response_standard           gender        0.076  0.873    0.498
#                                      age           0.404  0.533  0.009**
#                                      yrs_of_edu    0.696  0.737    0.088
#                                      intensity     0.290  0.708    0.249
#                                      suds          0.302  0.916    0.155
#                                      scalp_dist    0.314  0.799    0.775
# tms_site_response_individual_6mm     gender       0.025*  0.970    0.269
#                                      age           0.546  0.930    0.145
#                                      yrs_of_edu    0.155  0.347   0.028*
#                                      intensity     0.258  0.993    0.261
#                                      suds          0.052  0.902   0.047*
#                                      scalp_dist  0.003**  0.788    0.714
# tms_site_response_individual_10mm    gender        0.056  0.745    0.256
#                                      age           0.262  0.681    0.053
#                                      yrs_of_edu    0.389  0.699   0.041*
#                                      intensity     0.133  0.731    0.198
#                                      suds          0.175  0.924   0.033*
#                                      scalp_dist  0.005**  0.969    0.828
# tms_site_response_individual_14mm    gender        0.078  0.826    0.337
#                                      age           0.315  0.660   0.017*
#                                      yrs_of_edu    0.606  0.929    0.068
#                                      intensity     0.095  0.690    0.189
#                                      suds          0.276  0.976   0.043*
#                                      scalp_dist  0.008**  0.934    0.954
# tms_site_response_individual_14-10mm gender        0.108  0.855    0.411
#                                      age           0.333  0.676   0.011*
#                                      yrs_of_edu    0.722  0.962    0.107
#                                      intensity     0.094  0.691    0.207
#                                      suds          0.362  0.959    0.058
#                                      scalp_dist   0.012*  0.924    0.803
# tms_site_response_individual_10-6mm  gender        0.074  0.734    0.253
#                                      age           0.217  0.668   0.041*
#                                      yrs_of_edu    0.450  0.696    0.054
#                                      intensity     0.124  0.730    0.193
#                                      suds          0.229  0.916   0.031*
#                                      scalp_dist  0.006**  0.981    0.883
#
#                                                 R_aMFG L_pMFG R_pMFG   R_IFJ  \
# tms_site_response_standard           gender      0.051  0.590  0.761   0.107
#                                      age         0.273  0.721  0.118   0.740
#                                      yrs_of_edu  0.337  0.716  0.307   0.901
#                                      intensity   0.247  0.535  0.454   0.696
#                                      suds        0.773  0.551  0.994   0.079
#                                      scalp_dist  0.714  0.866  0.739   0.225
# tms_site_response_individual_6mm     gender      0.904  0.551  0.938   0.397
#                                      age         0.889  0.767  0.577   0.468
#                                      yrs_of_edu  0.512  0.833  0.714   0.359
#                                      intensity   0.903  0.269  0.749   0.425
#                                      suds        0.554  0.571  0.824   0.051
#                                      scalp_dist  0.315  0.265  0.464   0.305
# tms_site_response_individual_10mm    gender      0.488  0.476  0.987   0.114
#                                      age         0.681  0.929  0.419   0.539
#                                      yrs_of_edu  0.629  0.940  0.473   0.447
#                                      intensity   0.536  0.424  0.681   0.994
#                                      suds        0.726  0.616  0.915  0.033*
#                                      scalp_dist  0.382  0.298  0.671   0.345
# tms_site_response_individual_14mm    gender      0.318  0.496  0.924   0.053
#                                      age         0.448  0.950  0.319   0.570
#                                      yrs_of_edu  0.818  0.783  0.505   0.587
#                                      intensity   0.322  0.666  0.646   0.593
#                                      suds        0.802  0.832  0.986  0.038*
#                                      scalp_dist  0.498  0.423  0.961   0.331
# tms_site_response_individual_14-10mm gender      0.249  0.499  0.874  0.036*
#                                      age         0.352  0.859  0.277   0.605
#                                      yrs_of_edu  0.972  0.601  0.558   0.675
#                                      intensity   0.242  0.849  0.639   0.410
#                                      suds        0.851  0.965  0.960  0.046*
#                                      scalp_dist  0.574  0.551  0.869   0.344
# tms_site_response_individual_10-6mm  gender      0.396  0.467  0.983   0.074
#                                      age         0.615  0.972  0.376   0.568
#                                      yrs_of_edu  0.690  0.993  0.447   0.482
#                                      intensity   0.449  0.513  0.694   0.811
#                                      suds        0.775  0.644  0.951  0.032*
#                                      scalp_dist  0.411  0.336  0.741   0.374
#
#                                                  R_FEF   R_M1 R_preSMA  \
# tms_site_response_standard           gender      0.362  0.538    0.890
#                                      age         0.803  0.839    0.263
#                                      yrs_of_edu  0.962  0.480    0.234
#                                      intensity   0.075  0.172    0.478
#                                      suds        0.470  0.886    0.356
#                                      scalp_dist  0.928  0.945    0.807
# tms_site_response_individual_6mm     gender      0.606  0.365    0.314
#                                      age         0.691  0.780    0.099
#                                      yrs_of_edu  0.706  0.101    0.275
#                                      intensity   0.412  0.091    0.762
#                                      suds        0.369  0.666    0.281
#                                      scalp_dist  0.882  0.367    0.723
# tms_site_response_individual_10mm    gender      0.475  0.519    0.430
#                                      age         0.701  0.931    0.097
#                                      yrs_of_edu  0.788  0.216    0.203
#                                      intensity   0.183  0.142    0.607
#                                      suds        0.406  0.942    0.236
#                                      scalp_dist  0.837  0.589    0.939
# tms_site_response_individual_14mm    gender      0.472  0.682    0.649
#                                      age         0.715  0.740    0.098
#                                      yrs_of_edu  0.862  0.267    0.154
#                                      intensity   0.136  0.190    0.463
#                                      suds        0.487  0.738    0.241
#                                      scalp_dist  0.913  0.538    0.852
# tms_site_response_individual_14-10mm gender      0.480  0.810    0.811
#                                      age         0.701  0.647    0.102
#                                      yrs_of_edu  0.666  0.306    0.131
#                                      intensity   0.131  0.236    0.381
#                                      suds        0.526  0.603    0.246
#                                      scalp_dist  0.969  0.535    0.732
# tms_site_response_individual_10-6mm  gender      0.445  0.562    0.471
#                                      age         0.696  0.828    0.098
#                                      yrs_of_edu  0.795  0.236    0.190
#                                      intensity   0.149  0.160    0.565
#                                      suds        0.408  0.859    0.226
#                                      scalp_dist  0.819  0.604    0.994
#
#                                                    R_IPL
# tms_site_response_standard           gender        0.148
#                                      age           0.714
#                                      yrs_of_edu    0.674
#                                      intensity     0.911
#                                      suds          0.055
#                                      scalp_dist    0.172
# tms_site_response_individual_6mm     gender       0.020*
#                                      age           0.487
#                                      yrs_of_edu    0.358
#                                      intensity     0.580
#                                      suds        0.007**
#                                      scalp_dist    0.372
# tms_site_response_individual_10mm    gender        0.063
#                                      age           0.978
#                                      yrs_of_edu    0.355
#                                      intensity     0.711
#                                      suds         0.033*
#                                      scalp_dist    0.269
# tms_site_response_individual_14mm    gender        0.127
#                                      age           0.678
#                                      yrs_of_edu    0.443
#                                      intensity     0.748
#                                      suds          0.116
#                                      scalp_dist    0.156
# tms_site_response_individual_14-10mm gender        0.221
#                                      age           0.513
#                                      yrs_of_edu    0.523
#                                      intensity     0.774
#                                      suds          0.279
#                                      scalp_dist    0.121
# tms_site_response_individual_10-6mm  gender        0.106
#                                      age           0.848
#                                      yrs_of_edu    0.383
#                                      intensity     0.771
#                                      suds          0.068
#                                      scalp_dist    0.250
